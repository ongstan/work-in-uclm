# %%
ls ..
# Out:
# activity1/                dengue_features_train.csv  submission_format.csv
# dengue_features_test.csv  dengue_labels_train.csv

# %%
with open('./../submission_format.csv') as file:
    for i in file.readlines():
        print(i)
# Out:
# city,year,weekofyear,total_cases
#
# sj,2008,18,0
#
# sj,2008,19,0
#
# sj,2008,20,0
#
# sj,2008,21,0
#
# sj,2008,22,0
#
# sj,2008,23,0
#
# sj,2008,24,0
#
# sj,2008,25,0
#
# sj,2008,26,0
#
# sj,2008,27,0
#
# sj,2008,28,0
#
# sj,2008,29,0
#
# sj,2008,30,0
#
# sj,2008,31,0
#
# sj,2008,32,0
#
# sj,2008,33,0
#
# sj,2008,34,0
#
# sj,2008,35,0
#
# sj,2008,36,0
#
# sj,2008,37,0
#
# sj,2008,38,0
#
# sj,2008,39,0
#
# sj,2008,40,0
#
# sj,2008,41,0
#
# sj,2008,42,0
#
# sj,2008,43,0
#
# sj,2008,44,0
#
# sj,2008,45,0
#
# sj,2008,46,0
#
# sj,2008,47,0
#
# sj,2008,48,0
#
# sj,2008,49,0
#
# sj,2008,50,0
#
# sj,2008,51,0
#
# sj,2008,52,0
#
# sj,2009,1,0
#
# sj,2009,2,0
#
# sj,2009,3,0
#
# sj,2009,4,0
#
# sj,2009,5,0
#
# sj,2009,6,0
#
# sj,2009,7,0
#
# sj,2009,8,0
#
# sj,2009,9,0
#
# sj,2009,10,0
#
# sj,2009,11,0
#
# sj,2009,12,0
#
# sj,2009,13,0
#
# sj,2009,14,0
#
# sj,2009,15,0
#
# sj,2009,16,0
#
# sj,2009,17,0
#
# sj,2009,18,0
#
# sj,2009,19,0
#
# sj,2009,20,0
#
# sj,2009,21,0
#
# sj,2009,22,0
#
# ...

# %%
with open('./../dengue_labels_train.csv') as file:
    for i in file.readlines():
        print(i)
# Out:
# city,year,weekofyear,total_cases
#
# sj,1990,18,4
#
# sj,1990,19,5
#
# sj,1990,20,4
#
# sj,1990,21,3
#
# sj,1990,22,6
#
# sj,1990,23,2
#
# sj,1990,24,4
#
# sj,1990,25,5
#
# sj,1990,26,10
#
# sj,1990,27,6
#
# sj,1990,28,8
#
# sj,1990,29,2
#
# sj,1990,30,6
#
# sj,1990,31,17
#
# sj,1990,32,23
#
# sj,1990,33,13
#
# sj,1990,34,21
#
# sj,1990,35,28
#
# sj,1990,36,24
#
# sj,1990,37,20
#
# sj,1990,38,40
#
# sj,1990,39,27
#
# sj,1990,40,42
#
# sj,1990,41,33
#
# sj,1990,42,43
#
# sj,1990,43,37
#
# sj,1990,44,57
#
# sj,1990,45,71
#
# sj,1990,46,44
#
# sj,1990,47,56
#
# sj,1990,48,53
#
# sj,1990,49,52
#
# sj,1990,50,47
#
# sj,1990,51,26
#
# sj,1990,52,27
#
# sj,1991,1,21
#
# sj,1991,2,21
#
# sj,1991,3,26
#
# sj,1991,4,34
#
# sj,1991,5,37
#
# sj,1991,6,17
#
# sj,1991,7,19
#
# sj,1991,8,25
#
# sj,1991,9,18
#
# sj,1991,10,21
#
# sj,1991,11,17
#
# sj,1991,12,17
#
# sj,1991,13,16
#
# sj,1991,14,16
#
# sj,1991,15,15
#
# sj,1991,16,23
#
# sj,1991,17,16
#
# sj,1991,18,17
#
# sj,1991,19,12
#
# ...
